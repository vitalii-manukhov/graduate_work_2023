# %% [markdown]
# # Загрузка данных

# %% [markdown]
# Пакет os нужен для перемещения

# %%
import os
os.chdir("/kaggle/input/icbeb2023") # Перейдем в Input (только для чтения!)
# !ls # Посмотреть содержимое
# Out:
# X_train_ICBEB_all.npy	     y_train_ICBEB_all.npy
# X_train_ICBEB_diag.npy	     y_train_ICBEB_diag.npy
# X_train_ICBEB_form.npy	     y_train_ICBEB_form.npy
# X_train_ICBEB_rhythm.npy     y_train_ICBEB_rhythm.npy
# X_train_ICBEB_subdiag.npy    y_train_ICBEB_subdiag.npy
# X_train_ICBEB_superdiag.npy  y_train_ICBEB_superdiag.npy
# X_val_ICBEB_all.npy	     y_val_ICBEB_all.npy
# X_val_ICBEB_diag.npy	     y_val_ICBEB_diag.npy
# X_val_ICBEB_form.npy	     y_val_ICBEB_form.npy
# X_val_ICBEB_rhythm.npy	     y_val_ICBEB_rhythm.npy
# X_val_ICBEB_subdiag.npy      y_val_ICBEB_subdiag.npy
# X_val_ICBEB_superdiag.npy    y_val_ICBEB_superdiag.npy

# %%
os.chdir("/kaggle/working/") # Перейдем в Output
# !ls
# Out:
# __notebook_source__.ipynb

# %%
# Для работы с данными
import random
# Размеры на выбор в p раз меньше: P = {1, 2, 4, 8, 16, 32, 64}
def data_new_size(X, y, p = 1): # p - во сколько раз уменьшить (минимум 1 (default), максимум 64) 

    # Размер нового набора данных (в p раз меньше исходного)
    new_size = len(X) // p

    # Случайная выборка нового размера
    random_indices = random.sample(range(len(X_train)), new_size)
    X_batch = np.take(X, random_indices, axis=0)
    y_batch = np.take(y, random_indices, axis=0)
    return X_batch, y_batch

import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt   # plotting
import seaborn as sns   # plotting heatmap
import tensorflow as tf
import math
import pickle

# Для работы с моделями
from tensorflow import keras
from keras import layers

# Для метрик
from keras import backend as K
from keras.metrics import AUC, Recall, Precision, Accuracy, TruePositives, TrueNegatives, FalsePositives, FalseNegatives
from sklearn.metrics import fbeta_score, precision_score, recall_score, accuracy_score, roc_auc_score
from sklearn.metrics import auc, roc_curve
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix

# Код из учебника Жерона 
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.learning_rate, self.model.optimizer.learning_rate * self.factor)

def find_learning_rate(model, X, y, epochs=1, batch_size=32, min_rate=10**-5, max_rate=10):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = np.exp(np.log(max_rate / min_rate) / iterations)
    init_lr = K.get_value(model.optimizer.learning_rate)
    K.set_value(model.optimizer.learning_rate, min_rate)
    exp_lr = ExponentialLearningRate(factor)
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size,
                        callbacks=[exp_lr])
    K.set_value(model.optimizer.learning_rate, init_lr)
    model.set_weights(init_weights)
    return exp_lr.rates, exp_lr.losses

def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses)
    plt.gca().set_xscale('log')
    plt.hlines(min(losses), min(rates), max(rates))
    plt.axis([min(rates), max(rates), min(losses), (losses[0] + min(losses)) / 2])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_epoch_begin(self, epoch, logs=None):
        self.prev_loss = 0
    def on_batch_end(self, batch, logs=None):
        batch_loss = logs["loss"] * (batch + 1) - self.prev_loss * batch
        self.prev_loss = logs["loss"]
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(batch_loss)
        K.set_value(self.model.optimizer.learning_rate, self.model.optimizer.learning_rate * self.factor)

class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, rate)
        
# Загрузка ICBEB
def load_ICBEB(task):
  os.chdir("/kaggle/input/icbeb2023")
  if task == 'all':
    X_train = np.load('X_train_ICBEB_all.npy')
    y_train = np.load('y_train_ICBEB_all.npy')
    X_test = np.load('X_val_ICBEB_all.npy')
    y_test = np.load('y_val_ICBEB_all.npy')
  os.chdir("/kaggle/working/")
  return X_train, y_train, X_test, y_test

# Сериализация
def sp(obj, name): # sp = serialization_pickle ;name = *.pkl
    with open(name, 'wb') as pickle_out:
        pickle.dump(obj, pickle_out)

# Компиляция и обучение модели
def AUC_Keras(y_true, y_pred):
    auc = keras.metrics.AUC(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc

# Компиляция и обучение модели
def compile_fit(model, X_train, y_train, X_val = None, y_val = None, validation_split = 0.0, batch_size = None, epochs = None, early_stopping = None, model_checkpoint = None, onecycle = None):
  model.compile(loss = keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.experimental.AdamW(),
                metrics=['AUC'])
  
  if X_val == None:
    history = model.fit(X_train, y_train, 
                        epochs = epochs, 
                        batch_size = batch_size,
                        validation_data = None, 
                        validation_split=validation_split, 
                        callbacks=[onecycle, model_checkpoint, early_stopping])
    sp(history, 'history.pkl')
  else:
    history = model.fit(X_train, y_train, 
                        epochs = epochs,
                        batch_size = batch_size, 
                        validation_data = (X_val, y_val), 
                        validation_split=0.0, 
                        callbacks=[onecycle, model_checkpoint, early_stopping])
    sp(history, 'history.pkl')
  return history

# TP TN FP FN
def tp_tn_fp_fn(y_true, y_pred):
  TP = TruePositives()
  TN = TrueNegatives()
  FP = FalsePositives()
  FN = FalseNegatives()
  TP.update_state(y_true, y_pred)
  TN.update_state(y_true, y_pred)
  FP.update_state(y_true, y_pred)
  FN.update_state(y_true, y_pred)
  return TP.result().numpy(),  TN.result().numpy(),  FP.result().numpy(), FN.result().numpy() 

# Подсчет метрик
def calc_metrics(t, p, flag = 0): # t - y_true, p - y_pred
  y_true=np.argmax(t, axis=1)
  y_pred=np.argmax(p, axis=1)
  beta = 2

  f2_score = fbeta_score(y_true, y_pred, average='macro', beta=2)
  precision = precision_score(y_true, y_pred, average='macro')
  recall = recall_score(y_true, y_pred, average='macro')
  TP, TN, FP, FN = tp_tn_fp_fn(t, p)
  g2_score = TP/(TP+FP+beta*FN)
    
  sp(f2_score, 'f2_score.pkl')
  sp(g2_score, 'g2_score.pkl')
  sp(precision, 'precision.pkl')
  sp(recall, 'recall.pkl')
  sp(TP, 'TP.pkl')
  sp(TN, 'TN.pkl')
  sp(FP, 'FP.pkl')
  sp(FN, 'FN.pkl')
  sp(y_true, 'y_true_argmax.pkl')
  sp(y_pred, 'y_pred_argmax.pkl')
    
  if flag == 0:
    return f2_score, g2_score
  elif flag == 1:
    return f2_score, g2_score, precision, recall

# Таблица результатов
table_res_ptbxl = pd.DataFrame(columns = ('AUC', 'F2', 'G2'))

# Занесение новых результатов в таблицу
def edit_table(table, model, X, y, index_name): # X - X_test, y - y_test 
  score = model.evaluate(X, y)
  y_pr = model.predict(X)
  f2_score, g2_score = calc_metrics(y, y_pr, flag = 0)
  list_metrics = [score[1], f2_score, g2_score] # AUC, F2, G2
  table.loc[index_name] = list_metrics

  sp(score, 'score.pkl')
  sp(y_pr, 'y_pred.pkl')
  sp(y, 'y_test.pkl')
    
  return table

# График loss и accuracy
def plot_loss_and_accuracy_curves(_history):
  fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(18,6))
  axs[0].plot(_history.history['loss'], color='b', label='Training loss')
  axs[0].plot(_history.history['val_loss'], color='r', label='Validation loss')
  axs[0].set_title("Loss")
  axs[0].legend(loc='best', shadow=True)
  axs[1].plot(_history.history['auc'], color='b', label='Training accuracy')
  axs[1].plot(_history.history['val_auc'], color='r', label='Validation accuracy')
  axs[1].set_title("AUC")
  axs[1].legend(loc='best', shadow=True)
  plt.show()
  
# Работа с моделями lstm и lstm_bidir
def type_comp_fit_save_model_score(table, X_train, y_train, X_test, y_test, type_model, save_name, index_model_task, batch_size, epochs, onecycle):
  # количество классов
  num_classes = y_train.shape[1]
  sp(num_classes, 'num_classes.pkl')

  # Выбор архитектуры модели
  if type_model == 'lstm':
    inputs = keras.Input(shape=(1000, 12))
    x = layers.LSTM(units=256,
                    return_sequences=True,
                    stateful=False,
                    unroll=False)(inputs)
    x = layers.LeakyReLU()(x)
    x = layers.LSTM(units=256,
                    return_sequences=True, # True if concat
                    stateful=False,
                    unroll=False)(x)
    x = layers.LeakyReLU()(x)
    avg_pool = layers.GlobalAveragePooling1D()(x)
    max_pool = layers.GlobalMaxPooling1D()(x)
    concat = layers.Concatenate()([avg_pool, max_pool])
    outputs = layers.Dense(units=num_classes, activation='softmax')(concat)
    #outputs = layers.Dense(units=num_classes, activation='softmax')(x) # if concat off  
    model = keras.Model(inputs=inputs, outputs=outputs)
    print(model.summary())
    
    # Реализация раннего прекращения.
    checkpoint_filepath = './checkpoint_lstm/'
    model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                          save_weights_only=True,
                                                          save_best_only=True)
    early_stopping = keras.callbacks.EarlyStopping(patience=epochs//10,
                                                  restore_best_weights=True)
  elif type_model == 'lstm_bidir':
    inputs = keras.Input(shape=(1000, 12))
    x = layers.Bidirectional(layers.LSTM(units=256,
                             return_sequences = True,
                             stateful = False,
                             unroll = False))(inputs)
    x = layers.LeakyReLU()(x)
    x = layers.Bidirectional(layers.LSTM(units=256,
                             return_sequences = True,
                             stateful = False,
                             unroll = False))(x)
    x = layers.LeakyReLU()(x)
    avg_pool = layers.GlobalAveragePooling1D()(x)
    max_pool = layers.GlobalMaxPooling1D()(x)
    concat = layers.Concatenate()([avg_pool, max_pool])
    outputs = layers.Dense(units=num_classes, activation='softmax')(concat)
    model = keras.Model(inputs=inputs, outputs=outputs)
    
    model.build(input_shape = (None, 1000, 12)) # `input_shape` is the shape of the input data
    
    print(model.summary())
    
    sp(model, 'model.pkl')
    sp(model.summary(), 'model_summary().pkl')

    # Реализация раннего прекращения.
    checkpoint_filepath = './checkpoint_lstm_bidir/'
    model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                          save_weights_only=True,
                                                          save_best_only=True)
    early_stopping = keras.callbacks.EarlyStopping(patience=epochs//10,
                                                  restore_best_weights=True)
  
  # Обучение
  History = compile_fit(model, X_train, y_train, validation_split=0.1, batch_size=batch_size, epochs=epochs, early_stopping=early_stopping, model_checkpoint=model_checkpoint, onecycle=onecycle)

  # Сохранение модели
  model.save(save_name)

  # Построение графика
  plot_loss_and_accuracy_curves(History)

  # Сохранение в таблицу
  table = edit_table(table, model, X_test, y_test, index_model_task)

  sp(table, 'table.pkl')
  return table
                        
tf.random.set_seed(42)
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Обучение

# %% [markdown]
# ### lstm

# %% [markdown]
# ***task = 'all'***

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 64)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_0.zip /kaggle/working
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm (LSTM)                    (None, 1000, 256)    275456      ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 1000, 256)    0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  alAveragePooling1D)
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  xPooling1D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling1d[0][0]'
#                                                                  , 'global_max_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 9)            4617        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 9s 9s/step - loss: 0.6977 - auc: 0.6220 - val_loss: 0.6957 - val_auc: 0.6577
# Epoch 2/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6972 - auc: 0.6233 - val_loss: 0.6952 - val_auc: 0.6577
# Epoch 3/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.6967 - auc: 0.6258 - val_loss: 0.6946 - val_auc: 0.6507
# Epoch 4/200
# 1/1 [==============================] - 0s 303ms/step - loss: 0.6961 - auc: 0.6267 - val_loss: 0.6940 - val_auc: 0.6640
# Epoch 5/200
# 1/1 [==============================] - 0s 327ms/step - loss: 0.6954 - auc: 0.6260 - val_loss: 0.6933 - val_auc: 0.6640
# Epoch 6/200
# 1/1 [==============================] - 0s 302ms/step - loss: 0.6947 - auc: 0.6250 - val_loss: 0.6926 - val_auc: 0.6640
# Epoch 7/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.6939 - auc: 0.6259 - val_loss: 0.6918 - val_auc: 0.6617
# Epoch 8/200
# 1/1 [==============================] - 0s 366ms/step - loss: 0.6931 - auc: 0.6268 - val_loss: 0.6910 - val_auc: 0.6559
# Epoch 9/200
# 1/1 [==============================] - 0s 350ms/step - loss: 0.6923 - auc: 0.6293 - val_loss: 0.6902 - val_auc: 0.6536
# Epoch 10/200
# 1/1 [==============================] - 0s 351ms/step - loss: 0.6914 - auc: 0.6312 - val_loss: 0.6893 - val_auc: 0.6536
# Epoch 11/200
# 1/1 [==============================] - 0s 345ms/step - loss: 0.6904 - auc: 0.6286 - val_loss: 0.6883 - val_auc: 0.6507
# Epoch 12/200
# 1/1 [==============================] - 0s 326ms/step - loss: 0.6894 - auc: 0.6332 - val_loss: 0.6873 - val_auc: 0.6513
# Epoch 13/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6883 - auc: 0.6350 - val_loss: 0.6863 - val_auc: 0.6490
# Epoch 14/200
# 1/1 [==============================] - 0s 302ms/step - loss: 0.6872 - auc: 0.6381 - val_loss: 0.6852 - val_auc: 0.6513
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/table.pkl (deflated 33%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 97%)
#   adding: kaggle/working/FP.pkl (deflated 14%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/g2_score.pkl (deflated 16%)
#   adding: kaggle/working/TP.pkl (deflated 14%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/recall.pkl (deflated 13%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 32)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_1.zip /kaggle/working
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm_2 (LSTM)                  (None, 1000, 256)    275456      ['input_2[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_2[0][0]']
#
#  lstm_3 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_3[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 256)         0           ['leaky_re_lu_3[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_1 (Global  (None, 256)         0           ['leaky_re_lu_3[0][0]']
#  MaxPooling1D)
#
#  concatenate_1 (Concatenate)    (None, 512)          0           ['global_average_pooling1d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_1[0][0]']
#
#  dense_1 (Dense)                (None, 9)            4617        ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1
# Epoch 185/200
# 1/1 [==============================] - 0s 445ms/step - loss: 0.3217 - auc: 0.7597 - val_loss: 0.3501 - val_auc: 0.6825
# Epoch 186/200
# 1/1 [==============================] - 0s 450ms/step - loss: 0.3217 - auc: 0.7601 - val_loss: 0.3501 - val_auc: 0.6821
# Epoch 187/200
# 1/1 [==============================] - 0s 448ms/step - loss: 0.3216 - auc: 0.7600 - val_loss: 0.3501 - val_auc: 0.6821
# Epoch 188/200
# 1/1 [==============================] - 0s 446ms/step - loss: 0.3216 - auc: 0.7601 - val_loss: 0.3500 - val_auc: 0.6821
# Epoch 189/200
# 1/1 [==============================] - 0s 443ms/step - loss: 0.3216 - auc: 0.7603 - val_loss: 0.3500 - val_auc: 0.6821
# Epoch 190/200
# 1/1 [==============================] - 0s 450ms/step - loss: 0.3215 - auc: 0.7606 - val_loss: 0.3500 - val_auc: 0.6821
# Epoch 191/200
# 1/1 [==============================] - 0s 456ms/step - loss: 0.3215 - auc: 0.7605 - val_loss: 0.3500 - val_auc: 0.6822
# Epoch 192/200
# 1/1 [==============================] - 0s 439ms/step - loss: 0.3215 - auc: 0.7605 - val_loss: 0.3500 - val_auc: 0.6822
# Epoch 193/200
# 1/1 [==============================] - 0s 449ms/step - loss: 0.3215 - auc: 0.7605 - val_loss: 0.3500 - val_auc: 0.6822
# Epoch 194/200
# 1/1 [==============================] - 0s 449ms/step - loss: 0.3215 - auc: 0.7609 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 195/200
# 1/1 [==============================] - 0s 440ms/step - loss: 0.3215 - auc: 0.7610 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 196/200
# 1/1 [==============================] - 0s 486ms/step - loss: 0.3214 - auc: 0.7610 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 197/200
# 1/1 [==============================] - 0s 439ms/step - loss: 0.3214 - auc: 0.7610 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 198/200
# 1/1 [==============================] - 0s 440ms/step - loss: 0.3214 - auc: 0.7611 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 199/200
# 1/1 [==============================] - 0s 432ms/step - loss: 0.3214 - auc: 0.7611 - val_loss: 0.3499 - val_auc: 0.6824
# Epoch 200/200
# 1/1 [==============================] - 0s 433ms/step - loss: 0.3214 - auc: 0.7611 - val_loss: 0.3499 - val_auc: 0.6824
# 22/22 [==============================] - 1s 56ms/step - loss: 0.3380 - auc: 0.7178
# 22/22 [==============================] - 2s 48ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/TN.pkl (deflated 12%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/score.pkl (deflated 12%)
#   adding: kaggle/working/y_pred.pkl (deflated 10%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/table.pkl (deflated 33%)
#   adding: kaggle/working/all_0.zip (stored 0%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 92%)
#   adding: kaggle/working/FP.pkl (deflated 14%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/g2_score.pkl (deflated 16%)
#   adding: kaggle/working/TP.pkl (deflated 14%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/recall.pkl (deflated 11%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 16)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_2.zip /kaggle/working
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm_4 (LSTM)                  (None, 1000, 256)    275456      ['input_3[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_4[0][0]']
#
#  lstm_5 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu_4[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_5[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 256)         0           ['leaky_re_lu_5[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_2 (Global  (None, 256)         0           ['leaky_re_lu_5[0][0]']
#  MaxPooling1D)
#
#  concatenate_2 (Concatenate)    (None, 512)          0           ['global_average_pooling1d_2[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_2[0][0]']
#
#  dense_2 (Dense)                (None, 9)            4617        ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/200
# 2/2 [==============================] - 5s 1s/step - loss: 0.7082 - auc: 0.5438 - val_loss: 0.7064 - val_auc: 0.5145
# Epoch 2/200
# 2/2 [==============================] - 1s 341ms/step - loss: 0.7071 - auc: 0.5441 - val_loss: 0.7053 - val_auc: 0.5166
# Epoch 3/200
# 2/2 [==============================] - 1s 351ms/step - loss: 0.7058 - auc: 0.5457 - val_loss: 0.7041 - val_auc: 0.5139
# Epoch 4/200
# 2/2 [==============================] - 1s 415ms/step - loss: 0.7045 - auc: 0.5446 - val_loss: 0.7029 - val_auc: 0.5160
# Epoch 5/200
# 2/2 [==============================] - 1s 446ms/step - loss: 0.7030 - auc: 0.5461 - val_loss: 0.7015 - val_auc: 0.5167
# Epoch 6/200
# 2/2 [==============================] - 1s 354ms/step - loss: 0.7014 - auc: 0.5466 - val_loss: 0.7000 - val_auc: 0.5166
# Epoch 7/200
# 2/2 [==============================] - 1s 416ms/step - loss: 0.6998 - auc: 0.5470 - val_loss: 0.6985 - val_auc: 0.5156
# Epoch 8/200
# 2/2 [==============================] - 1s 502ms/step - loss: 0.6980 - auc: 0.5489 - val_loss: 0.6968 - val_auc: 0.5156
# Epoch 9/200
# 2/2 [==============================] - 1s 343ms/step - loss: 0.6961 - auc: 0.5495 - val_loss: 0.6951 - val_auc: 0.5115
# Epoch 10/200
# 2/2 [==============================] - 1s 416ms/step - loss: 0.6941 - auc: 0.5504 - val_loss: 0.6933 - val_auc: 0.5123
# Epoch 11/200
# 2/2 [==============================] - 1s 342ms/step - loss: 0.6921 - auc: 0.5530 - val_loss: 0.6914 - val_auc: 0.5120
# Epoch 12/200
# 2/2 [==============================] - 1s 418ms/step - loss: 0.6899 - auc: 0.5553 - val_loss: 0.6894 - val_auc: 0.5196
# Epoch 13/200
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6876 - auc: 0.5573 - val_loss: 0.6873 - val_auc: 0.5248
# Epoch 14/200
# 2/2 [==============================] - 1s 415ms/step - loss: 0.6852 - auc: 0.5569 - val_loss: 0.6851 - val_auc: 0.5301
# Epoch 15/200
# 2/2 [==============================] - 1s 350ms/step - loss: 0.6828 - auc: 0.5593 - val_loss: 0.6828 - val_auc: 0.5290
# Epoch 16/200
# 2/2 [==============================] - 1s 413ms/step - loss: 0.6802 - auc: 0.5618 - val_loss: 0.6805 - val_auc: 0.5117
# Epoch 17/200
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6775 - auc: 0.5621 - val_loss: 0.6780 - val_auc: 0.5101
# Epoch 18/200
# 2/2 [==============================] - 1s 390ms/step - loss: 0.6748 - auc: 0.5664 - val_loss: 0.6755 - val_auc: 0.5184
# Epoch 19/200
# 2/2 [==============================] - 1s 415ms/step - loss: 0.6718 - auc: 0.5686 - val_loss: 0.6728 - val_auc: 0.5083
# Epoch 20/200
# 2/2 [==============================] - 1s 343ms/step - loss: 0.6689 - auc: 0.5727 - val_loss: 0.6701 - val_auc: 0.5094
# Epoch 21/200
# 2/2 [==============================] - 1s 416ms/step - loss: 0.6657 - auc: 0.5795 - val_loss: 0.6672 - val_auc: 0.5146
# Epoch 22/200
# 2/2 [==============================] - 1s 416ms/step - loss: 0.6625 - auc: 0.5851 - val_loss: 0.6642 - val_auc: 0.5184
# Epoch 23/200
# 2/2 [==============================] - 1s 412ms/step - loss: 0.6590 - auc: 0.5901 - val_loss: 0.6610 - val_auc: 0.5068
# Epoch 24/200
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6555 - auc: 0.5941 - val_loss: 0.6577 - val_auc: 0.5122
# Epoch 25/200
# 2/2 [==============================] - 1s 342ms/step - loss: 0.6518 - auc: 0.5970 - val_loss: 0.6543 - val_auc: 0.5120
# Epoch 26/200
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6479 - auc: 0.5996 - val_loss: 0.6506 - val_auc: 0.5060
# Epoch 27/200
# 2/2 [==============================] - 1s 426ms/step - loss: 0.6438 - auc: 0.6072 - val_loss: 0.6468 - val_auc: 0.5157
# Epoch 28/200
# 2/2 [==============================] - 1s 338ms/step - loss: 0.6395 - auc: 0.6119 - val_loss: 0.6427 - val_auc: 0.5194
# Epoch 29/200
# 2/2 [==============================] - 1s 410ms/step - loss: 0.6349 - auc: 0.6148 - val_loss: 0.6385 - val_auc: 0.5148
# Epoch 30/200
# 2/2 [==============================] - 1s 340ms/step - loss: 0.6301 - auc: 0.6204 - val_loss: 0.6339 - val_auc: 0.5120
# Epoch 31/200
# 2/2 [==============================] - 1s 411ms/step - loss: 0.6250 - auc: 0.6232 - val_loss: 0.6290 - val_auc: 0.5131
# Epoch 32/200
# 2/2 [==============================] - 1s 421ms/step - loss: 0.6195 - auc: 0.6275 - val_loss: 0.6239 - val_auc: 0.5198
# Epoch 33/200
# 2/2 [==============================] - 1s 339ms/step - loss: 0.6137 - auc: 0.6334 - val_loss: 0.6183 - val_auc: 0.5069
# Epoch 34/200
# 2/2 [==============================] - 1s 415ms/step - loss: 0.6075 - auc: 0.6337 - val_loss: 0.6123 - val_auc: 0.5207
# Epoch 35/200
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6007 - auc: 0.6342 - val_loss: 0.6058 - val_auc: 0.5143
# Epoch 36/200
# 2/2 [==============================] - 1s 339ms/step - loss: 0.5934 - auc: 0.6334 - val_loss: 0.5987 - val_auc: 0.5165
# Epoch 37/200
# 2/2 [==============================] - 1s 413ms/step - loss: 0.5855 - auc: 0.6381 - val_loss: 0.5908 - val_auc: 0.5259
# Epoch 38/200
# 2/2 [==============================] - 1s 418ms/step - loss: 0.5767 - auc: 0.6415 - val_loss: 0.5820 - val_auc: 0.5191
# Epoch 39/200
# 2/2 [==============================] - 1s 416ms/step - loss: 0.5671 - auc: 0.6419 - val_loss: 0.5722 - val_auc: 0.5227
# Epoch 40/200
# 2/2 [==============================] - 1s 412ms/step - loss: 0.5562 - auc: 0.6442 - val_loss: 0.5608 - val_auc: 0.5301
# Epoch 41/200
# 2/2 [==============================] - 1s 418ms/step - loss: 0.5440 - auc: 0.6409 - val_loss: 0.5476 - val_auc: 0.5295
# Epoch 42/200
# Epoch 124/200
# 2/2 [==============================] - 1s 343ms/step - loss: 0.3039 - auc: 0.7860 - val_loss: 0.3122 - val_auc: 0.7730
# Epoch 125/200
# 2/2 [==============================] - 1s 359ms/step - loss: 0.3032 - auc: 0.7851 - val_loss: 0.3122 - val_auc: 0.7727
# Epoch 126/200
# 2/2 [==============================] - 1s 361ms/step - loss: 0.3024 - auc: 0.7865 - val_loss: 0.3134 - val_auc: 0.7683
# Epoch 127/200
# 2/2 [==============================] - 1s 440ms/step - loss: 0.3017 - auc: 0.7879 - val_loss: 0.3115 - val_auc: 0.7736
# Epoch 128/200
# 2/2 [==============================] - 1s 442ms/step - loss: 0.3011 - auc: 0.7874 - val_loss: 0.3097 - val_auc: 0.7787
# Epoch 129/200
# 2/2 [==============================] - 1s 346ms/step - loss: 0.3008 - auc: 0.7882 - val_loss: 0.3096 - val_auc: 0.7781
# Epoch 130/200
# 2/2 [==============================] - 1s 341ms/step - loss: 0.3001 - auc: 0.7896 - val_loss: 0.3096 - val_auc: 0.7751
# Epoch 131/200
# 2/2 [==============================] - 1s 345ms/step - loss: 0.2991 - auc: 0.7901 - val_loss: 0.3095 - val_auc: 0.7718
# Epoch 132/200
# 2/2 [==============================] - 1s 334ms/step - loss: 0.2990 - auc: 0.7906 - val_loss: 0.3091 - val_auc: 0.7746
# Epoch 133/200
# 2/2 [==============================] - 1s 343ms/step - loss: 0.2982 - auc: 0.7937 - val_loss: 0.3065 - val_auc: 0.7831
# Epoch 134/200
# 2/2 [==============================] - 1s 432ms/step - loss: 0.2981 - auc: 0.7934 - val_loss: 0.3051 - val_auc: 0.7875
# Epoch 135/200
# 2/2 [==============================] - 1s 286ms/step - loss: 0.2980 - auc: 0.7944 - val_loss: 0.3053 - val_auc: 0.7828
# Epoch 136/200
# 2/2 [==============================] - 1s 291ms/step - loss: 0.2986 - auc: 0.7872 - val_loss: 0.3069 - val_auc: 0.7753
# Epoch 137/200
# 2/2 [==============================] - 1s 286ms/step - loss: 0.3024 - auc: 0.7788 - val_loss: 0.3165 - val_auc: 0.7446
# Epoch 138/200
# 2/2 [==============================] - 1s 287ms/step - loss: 0.3020 - auc: 0.7783 - val_loss: 0.3275 - val_auc: 0.7147
# Epoch 139/200
# 2/2 [==============================] - 1s 282ms/step - loss: 0.3051 - auc: 0.7696 - val_loss: 0.3297 - val_auc: 0.7109
# Epoch 140/200
# 2/2 [==============================] - 1s 356ms/step - loss: 0.3050 - auc: 0.7708 - val_loss: 0.3239 - val_auc: 0.7271
# Epoch 141/200
# 2/2 [==============================] - 1s 356ms/step - loss: 0.3018 - auc: 0.7782 - val_loss: 0.3129 - val_auc: 0.7541
# Epoch 142/200
# 2/2 [==============================] - 1s 340ms/step - loss: 0.2979 - auc: 0.7887 - val_loss: 0.3010 - val_auc: 0.7855
# Epoch 143/200
# 2/2 [==============================] - 1s 287ms/step - loss: 0.2979 - auc: 0.7865 - val_loss: 0.3010 - val_auc: 0.7907
# Epoch 144/200
# 2/2 [==============================] - 1s 344ms/step - loss: 0.2855 - auc: 0.8134 - val_loss: 0.2966 - val_auc: 0.7898
# Epoch 186/200
# 2/2 [==============================] - 1s 342ms/step - loss: 0.2854 - auc: 0.8134 - val_loss: 0.2966 - val_auc: 0.7894
# Epoch 187/200
# 2/2 [==============================] - 1s 359ms/step - loss: 0.2853 - auc: 0.8137 - val_loss: 0.2966 - val_auc: 0.7897
# Epoch 188/200
# 2/2 [==============================] - 1s 289ms/step - loss: 0.2853 - auc: 0.8136 - val_loss: 0.2966 - val_auc: 0.7892
# Epoch 189/200
# 2/2 [==============================] - 1s 359ms/step - loss: 0.2853 - auc: 0.8135 - val_loss: 0.2966 - val_auc: 0.7887
# Epoch 190/200
# 2/2 [==============================] - 1s 385ms/step - loss: 0.2852 - auc: 0.8135 - val_loss: 0.2965 - val_auc: 0.7885
# Epoch 191/200
# 2/2 [==============================] - 1s 491ms/step - loss: 0.2851 - auc: 0.8135 - val_loss: 0.2964 - val_auc: 0.7882
# Epoch 192/200
# 2/2 [==============================] - 1s 419ms/step - loss: 0.2851 - auc: 0.8138 - val_loss: 0.2964 - val_auc: 0.7882
# Epoch 193/200
# 2/2 [==============================] - 1s 285ms/step - loss: 0.2850 - auc: 0.8138 - val_loss: 0.2964 - val_auc: 0.7884
# Epoch 194/200
# 2/2 [==============================] - 1s 360ms/step - loss: 0.2850 - auc: 0.8140 - val_loss: 0.2965 - val_auc: 0.7885
# Epoch 195/200
# 2/2 [==============================] - 1s 293ms/step - loss: 0.2850 - auc: 0.8137 - val_loss: 0.2965 - val_auc: 0.7881
# Epoch 196/200
# 2/2 [==============================] - 1s 286ms/step - loss: 0.2849 - auc: 0.8138 - val_loss: 0.2965 - val_auc: 0.7880
# Epoch 197/200
# 2/2 [==============================] - 1s 285ms/step - loss: 0.2849 - auc: 0.8138 - val_loss: 0.2965 - val_auc: 0.7884
# Epoch 198/200
# 2/2 [==============================] - 1s 357ms/step - loss: 0.2849 - auc: 0.8137 - val_loss: 0.2966 - val_auc: 0.7884
# Epoch 199/200
# 2/2 [==============================] - 1s 282ms/step - loss: 0.2849 - auc: 0.8137 - val_loss: 0.2966 - val_auc: 0.7885
# Epoch 200/200
# 2/2 [==============================] - 1s 356ms/step - loss: 0.2849 - auc: 0.8136 - val_loss: 0.2966 - val_auc: 0.7885
# 22/22 [==============================] - 1s 53ms/step - loss: 0.3012 - auc: 0.7744
# 22/22 [==============================] - 2s 48ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/TN.pkl (deflated 13%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/score.pkl (deflated 21%)
#   adding: kaggle/working/y_pred.pkl (deflated 9%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/table.pkl (deflated 32%)
#   adding: kaggle/working/all_0.zip (stored 0%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 91%)
#   adding: kaggle/working/FP.pkl (deflated 13%)
#   adding: kaggle/working/f2_score.pkl (deflated 12%)
#   adding: kaggle/working/all_1.zip (stored 0%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/g2_score.pkl (deflated 11%)
#   adding: kaggle/working/TP.pkl (deflated 13%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/recall.pkl (deflated 11%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 8)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_3.zip /kaggle/working
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm_6 (LSTM)                  (None, 1000, 256)    275456      ['input_4[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_6[0][0]']
#
#  lstm_7 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu_6[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_7[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 256)         0           ['leaky_re_lu_7[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_3 (Global  (None, 256)         0           ['leaky_re_lu_7[0][0]']
#  MaxPooling1D)
#
#  concatenate_3 (Concatenate)    (None, 512)          0           ['global_average_pooling1d_3[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_3[0][0]']
#
#  dense_3 (Dense)                (None, 9)            4617        ['concatenate_3[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1
# 3/3 [==============================] - 1s 482ms/step - loss: 0.2660 - auc: 0.8411 - val_loss: 0.2940 - val_auc: 0.7809
# Epoch 186/200
# 3/3 [==============================] - 1s 424ms/step - loss: 0.2658 - auc: 0.8411 - val_loss: 0.2941 - val_auc: 0.7800
# Epoch 187/200
# 3/3 [==============================] - 1s 427ms/step - loss: 0.2653 - auc: 0.8432 - val_loss: 0.2941 - val_auc: 0.7812
# Epoch 188/200
# 3/3 [==============================] - 1s 459ms/step - loss: 0.2648 - auc: 0.8440 - val_loss: 0.2939 - val_auc: 0.7821
# Epoch 189/200
# 3/3 [==============================] - 1s 457ms/step - loss: 0.2644 - auc: 0.8448 - val_loss: 0.2937 - val_auc: 0.7826
# Epoch 190/200
# 3/3 [==============================] - 1s 457ms/step - loss: 0.2640 - auc: 0.8452 - val_loss: 0.2935 - val_auc: 0.7820
# Epoch 191/200
# 3/3 [==============================] - 1s 451ms/step - loss: 0.2639 - auc: 0.8451 - val_loss: 0.2933 - val_auc: 0.7817
# Epoch 192/200
# 3/3 [==============================] - 1s 425ms/step - loss: 0.2635 - auc: 0.8463 - val_loss: 0.2936 - val_auc: 0.7818
# Epoch 193/200
# 3/3 [==============================] - 1s 457ms/step - loss: 0.2632 - auc: 0.8467 - val_loss: 0.2931 - val_auc: 0.7812
# Epoch 194/200
# 3/3 [==============================] - 1s 481ms/step - loss: 0.2629 - auc: 0.8468 - val_loss: 0.2928 - val_auc: 0.7819
# Epoch 195/200
# 3/3 [==============================] - 1s 451ms/step - loss: 0.2627 - auc: 0.8470 - val_loss: 0.2929 - val_auc: 0.7823
# Epoch 196/200
# 3/3 [==============================] - 1s 427ms/step - loss: 0.2629 - auc: 0.8476 - val_loss: 0.2956 - val_auc: 0.7790
# Epoch 197/200
# 3/3 [==============================] - 1s 424ms/step - loss: 0.2631 - auc: 0.8483 - val_loss: 0.2961 - val_auc: 0.7778
# Epoch 198/200
# 3/3 [==============================] - 1s 449ms/step - loss: 0.2630 - auc: 0.8487 - val_loss: 0.2959 - val_auc: 0.7787
# Epoch 199/200
# 3/3 [==============================] - 1s 455ms/step - loss: 0.2625 - auc: 0.8491 - val_loss: 0.2951 - val_auc: 0.7791
# Epoch 200/200
# 3/3 [==============================] - 1s 452ms/step - loss: 0.2618 - auc: 0.8493 - val_loss: 0.2944 - val_auc: 0.7800
# 22/22 [==============================] - 1s 52ms/step - loss: 0.2743 - auc: 0.8231
# 22/22 [==============================] - 2s 48ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/all_2.zip (stored 0%)
#   adding: kaggle/working/TN.pkl (deflated 13%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/score.pkl (deflated 18%)
#   adding: kaggle/working/y_pred.pkl (deflated 9%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/table.pkl (deflated 31%)
#   adding: kaggle/working/all_0.zip (stored 0%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 90%)
#   adding: kaggle/working/FP.pkl (deflated 13%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)
#   adding: kaggle/working/all_1.zip (stored 0%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/g2_score.pkl (deflated 11%)
#   adding: kaggle/working/TP.pkl (deflated 13%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/recall.pkl (deflated 11%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 4)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_4.zip /kaggle/working
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm (LSTM)                    (None, 1000, 256)    275456      ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 1000, 256)    0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  alAveragePooling1D)
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  xPooling1D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling1d[0][0]'
#                                                                  , 'global_max_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 9)            4617        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1
# Epoch 165/200
# 6/6 [==============================] - 2s 409ms/step - loss: 0.2077 - auc: 0.9034 - val_loss: 0.2418 - val_auc: 0.8601
# Epoch 166/200
# 6/6 [==============================] - 2s 414ms/step - loss: 0.2072 - auc: 0.9040 - val_loss: 0.2433 - val_auc: 0.8575
# Epoch 167/200
# 6/6 [==============================] - 2s 416ms/step - loss: 0.2069 - auc: 0.9043 - val_loss: 0.2434 - val_auc: 0.8571
# Epoch 168/200
# 6/6 [==============================] - 2s 412ms/step - loss: 0.2074 - auc: 0.9047 - val_loss: 0.2445 - val_auc: 0.8591
# Epoch 169/200
# 6/6 [==============================] - 2s 411ms/step - loss: 0.2091 - auc: 0.9015 - val_loss: 0.2559 - val_auc: 0.8390
# Epoch 170/200
# 6/6 [==============================] - 2s 408ms/step - loss: 0.2069 - auc: 0.9026 - val_loss: 0.2426 - val_auc: 0.8571
# Epoch 171/200
# 6/6 [==============================] - 2s 411ms/step - loss: 0.2052 - auc: 0.9058 - val_loss: 0.2401 - val_auc: 0.8639
# Epoch 172/200
# 6/6 [==============================] - 2s 408ms/step - loss: 0.2400 - auc: 0.8620 - val_loss: 0.2865 - val_auc: 0.7942
# Epoch 173/200
# 6/6 [==============================] - 2s 410ms/step - loss: 0.2406 - auc: 0.8603 - val_loss: 0.2685 - val_auc: 0.8236
# Epoch 174/200
# 6/6 [==============================] - 2s 408ms/step - loss: 0.2299 - auc: 0.8823 - val_loss: 0.2569 - val_auc: 0.8427
# Epoch 175/200
# 6/6 [==============================] - 2s 407ms/step - loss: 0.2228 - auc: 0.8907 - val_loss: 0.2563 - val_auc: 0.8455
# Epoch 176/200
# 6/6 [==============================] - 2s 413ms/step - loss: 0.2190 - auc: 0.8942 - val_loss: 0.2514 - val_auc: 0.8519
# Epoch 177/200
# 6/6 [==============================] - 2s 408ms/step - loss: 0.2186 - auc: 0.8971 - val_loss: 0.2541 - val_auc: 0.8486
# Epoch 178/200
# 6/6 [==============================] - 2s 408ms/step - loss: 0.2151 - auc: 0.8977 - val_loss: 0.2506 - val_auc: 0.8508
# Epoch 179/200
# 6/6 [==============================] - 3s 420ms/step - loss: 0.2118 - auc: 0.8994 - val_loss: 0.2466 - val_auc: 0.8554
# 22/22 [==============================] - 1s 49ms/step - loss: 0.2390 - auc: 0.8649
# 22/22 [==============================] - 2s 47ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/y_pred.pkl (deflated 7%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/table.pkl (deflated 32%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/TN.pkl (deflated 12%)
#   adding: kaggle/working/g2_score.pkl (deflated 13%)
#   adding: kaggle/working/recall.pkl (deflated 11%)
#   adding: kaggle/working/FP.pkl (deflated 13%)
#   adding: kaggle/working/score.pkl (deflated 15%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 89%)
#   adding: kaggle/working/TP.pkl (deflated 13%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 2)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_5.zip /kaggle/working
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm (LSTM)                    (None, 1000, 256)    275456      ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 1000, 256)    0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  alAveragePooling1D)
#
#  global_max_pooling1d (GlobalMa  (None, 256)         0           ['leaky_re_lu_1[0][0]']
#  xPooling1D)
#
#  concatenate (Concatenate)      (None, 512)          0           ['global_average_pooling1d[0][0]'
#                                                                  , 'global_max_pooling1d[0][0]']
#
#  dense (Dense)                  (None, 9)            4617        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1
# Epoch 44/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.3253 - auc: 0.7495 - val_loss: 0.3220 - val_auc: 0.7563
# Epoch 45/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.3239 - auc: 0.7531 - val_loss: 0.3203 - val_auc: 0.7599
# Epoch 46/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.3216 - auc: 0.7578 - val_loss: 0.3178 - val_auc: 0.7662
# Epoch 47/200
# 11/11 [==============================] - 5s 434ms/step - loss: 0.3196 - auc: 0.7601 - val_loss: 0.3182 - val_auc: 0.7671
# Epoch 48/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.3205 - auc: 0.7564 - val_loss: 0.3176 - val_auc: 0.7667
# Epoch 49/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.3170 - auc: 0.7665 - val_loss: 0.3116 - val_auc: 0.7784
# Epoch 50/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.3120 - auc: 0.7771 - val_loss: 0.3102 - val_auc: 0.7825
# Epoch 51/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.3093 - auc: 0.7796 - val_loss: 0.3040 - val_auc: 0.7917
# Epoch 52/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.3068 - auc: 0.7809 - val_loss: 0.3003 - val_auc: 0.7975
# Epoch 53/200
# 11/11 [==============================] - 5s 431ms/step - loss: 0.3054 - auc: 0.7923 - val_loss: 0.3229 - val_auc: 0.7571
# Epoch 54/200
# 11/11 [==============================] - 5s 433ms/step - loss: 0.3248 - auc: 0.7471 - val_loss: 0.3111 - val_auc: 0.7771
# Epoch 55/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.3118 - auc: 0.7961 - val_loss: 0.3086 - val_auc: 0.8124
# Epoch 56/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.3052 - auc: 0.8066 - val_loss: 0.3007 - val_auc: 0.8049
# Epoch 57/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.3002 - auc: 0.8049 - val_loss: 0.2955 - val_auc: 0.8166
# Epoch 58/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.2956 - auc: 0.8151 - val_loss: 0.2904 - val_auc: 0.8180
# Epoch 59/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.2915 - auc: 0.8175 - val_loss: 0.2866 - val_auc: 0.8195
# Epoch 60/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2886 - auc: 0.8208 - val_loss: 0.2859 - val_auc: 0.8285
# Epoch 61/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2852 - auc: 0.8255 - val_loss: 0.2805 - val_auc: 0.8324
# Epoch 62/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.2819 - auc: 0.8300 - val_loss: 0.2758 - val_auc: 0.8328
# Epoch 63/200
# 11/11 [==============================] - 5s 449ms/step - loss: 0.2773 - auc: 0.8351 - val_loss: 0.2733 - val_auc: 0.8343
# Epoch 64/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.2754 - auc: 0.8378 - val_loss: 0.2706 - val_auc: 0.8359
# Epoch 65/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.2697 - auc: 0.8453 - val_loss: 0.2650 - val_auc: 0.8487
# Epoch 66/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.2678 - auc: 0.8460 - val_loss: 0.2636 - val_auc: 0.8499
# Epoch 67/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.2652 - auc: 0.8502 - val_loss: 0.2600 - val_auc: 0.8528
# Epoch 68/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.2612 - auc: 0.8533 - val_loss: 0.2572 - val_auc: 0.8567
# Epoch 69/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2585 - auc: 0.8557 - val_loss: 0.2541 - val_auc: 0.8594
# Epoch 70/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2552 - auc: 0.8601 - val_loss: 0.2514 - val_auc: 0.8634
# Epoch 71/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.2534 - auc: 0.8629 - val_loss: 0.2497 - val_auc: 0.8646
# Epoch 72/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.2517 - auc: 0.8650 - val_loss: 0.2478 - val_auc: 0.8663
# Epoch 73/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.2486 - auc: 0.8674 - val_loss: 0.2460 - val_auc: 0.8680
# Epoch 74/200
# 11/11 [==============================] - 5s 433ms/step - loss: 0.2483 - auc: 0.8653 - val_loss: 0.2463 - val_auc: 0.8718
# Epoch 75/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2461 - auc: 0.8735 - val_loss: 0.2469 - val_auc: 0.8660
# Epoch 76/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.2448 - auc: 0.8742 - val_loss: 0.2428 - val_auc: 0.8733
# Epoch 77/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.2426 - auc: 0.8716 - val_loss: 0.2434 - val_auc: 0.8659
# Epoch 78/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2410 - auc: 0.8720 - val_loss: 0.2394 - val_auc: 0.8720
# Epoch 79/200
# 11/11 [==============================] - 5s 435ms/step - loss: 0.2387 - auc: 0.8762 - val_loss: 0.2383 - val_auc: 0.8743
# Epoch 80/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.2371 - auc: 0.8794 - val_loss: 0.2367 - val_auc: 0.8788
# Epoch 81/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2347 - auc: 0.8776 - val_loss: 0.2390 - val_auc: 0.8755
# Epoch 82/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2374 - auc: 0.8778 - val_loss: 0.2348 - val_auc: 0.8805
# Epoch 83/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.2332 - auc: 0.8817 - val_loss: 0.2327 - val_auc: 0.8827
# Epoch 84/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.2296 - auc: 0.8871 - val_loss: 0.2297 - val_auc: 0.8874
# Epoch 85/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2285 - auc: 0.8861 - val_loss: 0.2335 - val_auc: 0.8799
# Epoch 86/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.2325 - auc: 0.8813 - val_loss: 0.2389 - val_auc: 0.8727
# Epoch 87/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2365 - auc: 0.8732 - val_loss: 0.2348 - val_auc: 0.8829
# Epoch 88/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.2312 - auc: 0.8843 - val_loss: 0.2300 - val_auc: 0.8860
# Epoch 89/200
# 11/11 [==============================] - 5s 447ms/step - loss: 0.2271 - auc: 0.8852 - val_loss: 0.2274 - val_auc: 0.8864
# Epoch 90/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.2251 - auc: 0.8895 - val_loss: 0.2266 - val_auc: 0.8868
# Epoch 91/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.2239 - auc: 0.8915 - val_loss: 0.2276 - val_auc: 0.8879
# Epoch 92/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.2194 - auc: 0.8978 - val_loss: 0.2208 - val_auc: 0.8949
# Epoch 93/200
# 11/11 [==============================] - 5s 435ms/step - loss: 0.2166 - auc: 0.8975 - val_loss: 0.2211 - val_auc: 0.8955
# Epoch 94/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.2157 - auc: 0.9017 - val_loss: 0.2166 - val_auc: 0.9017
# Epoch 95/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2147 - auc: 0.9017 - val_loss: 0.2204 - val_auc: 0.8945
# Epoch 96/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.2136 - auc: 0.8999 - val_loss: 0.2181 - val_auc: 0.8965
# Epoch 97/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2100 - auc: 0.9043 - val_loss: 0.2147 - val_auc: 0.9017
# Epoch 98/200
# 11/11 [==============================] - 5s 444ms/step - loss: 0.2106 - auc: 0.9018 - val_loss: 0.2138 - val_auc: 0.8996
# Epoch 99/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.2088 - auc: 0.9040 - val_loss: 0.2134 - val_auc: 0.9030
# Epoch 100/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.2078 - auc: 0.9078 - val_loss: 0.2123 - val_auc: 0.9046
# Epoch 101/200
# 11/11 [==============================] - 5s 445ms/step - loss: 0.2041 - auc: 0.9068 - val_loss: 0.2092 - val_auc: 0.9061
# Epoch 102/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.2133 - auc: 0.8991 - val_loss: 0.2342 - val_auc: 0.8794
# Epoch 103/200
# 11/11 [==============================] - 5s 442ms/step - loss: 0.2445 - auc: 0.8635 - val_loss: 0.2567 - val_auc: 0.8604
# Epoch 104/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.2501 - auc: 0.8640 - val_loss: 0.2467 - val_auc: 0.8583
# Epoch 187/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.1577 - auc: 0.9421 - val_loss: 0.1753 - val_auc: 0.9326
# Epoch 188/200
# 11/11 [==============================] - 5s 437ms/step - loss: 0.1574 - auc: 0.9419 - val_loss: 0.1754 - val_auc: 0.9309
# Epoch 189/200
# 11/11 [==============================] - 5s 441ms/step - loss: 0.1571 - auc: 0.9418 - val_loss: 0.1764 - val_auc: 0.9308
# Epoch 190/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.1573 - auc: 0.9415 - val_loss: 0.1740 - val_auc: 0.9327
# Epoch 191/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.1565 - auc: 0.9417 - val_loss: 0.1747 - val_auc: 0.9324
# Epoch 192/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.1563 - auc: 0.9424 - val_loss: 0.1741 - val_auc: 0.9328
# Epoch 193/200
# 11/11 [==============================] - 5s 432ms/step - loss: 0.1562 - auc: 0.9415 - val_loss: 0.1788 - val_auc: 0.9280
# Epoch 194/200
# 11/11 [==============================] - 5s 434ms/step - loss: 0.1632 - auc: 0.9375 - val_loss: 0.1773 - val_auc: 0.9328
# Epoch 195/200
# 11/11 [==============================] - 5s 439ms/step - loss: 0.1574 - auc: 0.9417 - val_loss: 0.1740 - val_auc: 0.9299
# Epoch 196/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.1567 - auc: 0.9416 - val_loss: 0.1745 - val_auc: 0.9327
# Epoch 197/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.1553 - auc: 0.9423 - val_loss: 0.1728 - val_auc: 0.9348
# Epoch 198/200
# 11/11 [==============================] - 5s 443ms/step - loss: 0.1552 - auc: 0.9426 - val_loss: 0.1725 - val_auc: 0.9344
# Epoch 199/200
# 11/11 [==============================] - 5s 440ms/step - loss: 0.1542 - auc: 0.9436 - val_loss: 0.1737 - val_auc: 0.9344
# Epoch 200/200
# 11/11 [==============================] - 5s 438ms/step - loss: 0.1541 - auc: 0.9432 - val_loss: 0.1728 - val_auc: 0.9335
# 22/22 [==============================] - 1s 52ms/step - loss: 0.1900 - auc: 0.9103
# 22/22 [==============================] - 2s 48ms/step
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/score.pkl (deflated 15%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/table.pkl (deflated 32%)
#   adding: kaggle/working/g2_score.pkl (deflated 11%)
#   adding: kaggle/working/recall.pkl (deflated 11%)
#   adding: kaggle/working/TN.pkl (deflated 12%)
#   adding: kaggle/working/TP.pkl (deflated 13%)
#   adding: kaggle/working/y_pred.pkl (deflated 6%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 88%)
#   adding: kaggle/working/FP.pkl (deflated 13%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)

# %%
X_train, y_train, X_test, y_test = load_ICBEB(task = 'all')
X_train, y_train = data_new_size(X_train, y_train, 1)
batch_size = 256
epochs = 200
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * epochs, max_rate=0.0001)
table_res_ptbxl = type_comp_fit_save_model_score(table_res_ptbxl, X_train, y_train, X_test, y_test,type_model = 'lstm', save_name = 'model_lstm_all',index_model_task = 'lstm_all', batch_size=batch_size, epochs=epochs, onecycle=onecycle)
del(X_train)
del(y_train)
del(X_test)
del(y_test)
# !cd /kaggle/working
#!ls
# !zip -r all_6.zip /kaggle/working
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 1000, 12)]   0           []
#
#  lstm_2 (LSTM)                  (None, 1000, 256)    275456      ['input_2[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_2[0][0]']
#
#  lstm_3 (LSTM)                  (None, 1000, 256)    525312      ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 1000, 256)    0           ['lstm_3[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 256)         0           ['leaky_re_lu_3[0][0]']
#  obalAveragePooling1D)
#
#  global_max_pooling1d_1 (Global  (None, 256)         0           ['leaky_re_lu_3[0][0]']
#  MaxPooling1D)
#
#  concatenate_1 (Concatenate)    (None, 512)          0           ['global_average_pooling1d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling1d_1[0][0]']
#
#  dense_1 (Dense)                (None, 9)            4617        ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 805,385
# Trainable params: 805,385
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1
# 22/22 [==============================] - 9s 428ms/step - loss: 0.2155 - auc: 0.8978 - val_loss: 0.2244 - val_auc: 0.8909
# Epoch 106/200
# 22/22 [==============================] - 10s 437ms/step - loss: 0.2322 - auc: 0.8780 - val_loss: 0.2758 - val_auc: 0.8348
# Epoch 107/200
# 22/22 [==============================] - 9s 430ms/step - loss: 0.2524 - auc: 0.8627 - val_loss: 0.2420 - val_auc: 0.8773
# Epoch 108/200
# 22/22 [==============================] - 9s 429ms/step - loss: 0.2316 - auc: 0.8823 - val_loss: 0.2350 - val_auc: 0.8768
# Epoch 109/200
# 22/22 [==============================] - 10s 436ms/step - loss: 0.2257 - auc: 0.8859 - val_loss: 0.2317 - val_auc: 0.8829
# Epoch 110/200
# 22/22 [==============================] - 9s 428ms/step - loss: 0.2212 - auc: 0.8916 - val_loss: 0.2273 - val_auc: 0.8858
# Epoch 111/200
# 22/22 [==============================] - 10s 437ms/step - loss: 0.2175 - auc: 0.8943 - val_loss: 0.2258 - val_auc: 0.8879
# 22/22 [==============================] - 1s 52ms/step - loss: 0.2131 - auc: 0.8991
# 22/22 [==============================] - 2s 48ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/FN.pkl (deflated 13%)
#   adding: kaggle/working/model_lstm_all/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/saved_model.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/keras_metadata.pb (deflated 90%)
#   adding: kaggle/working/model_lstm_all/variables/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/variables/variables.index (deflated 62%)
#   adding: kaggle/working/model_lstm_all/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/model_lstm_all/assets/ (stored 0%)
#   adding: kaggle/working/model_lstm_all/fingerprint.pb (stored 0%)
#   adding: kaggle/working/history.pkl (deflated 7%)
#   adding: kaggle/working/score.pkl (deflated 12%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/y_test.pkl (deflated 96%)
#   adding: kaggle/working/num_classes.pkl (stored 0%)
#   adding: kaggle/working/table.pkl (deflated 31%)
#   adding: kaggle/working/g2_score.pkl (deflated 11%)
#   adding: kaggle/working/all_5.zip (stored 0%)
#   adding: kaggle/working/recall.pkl (deflated 11%)
#   adding: kaggle/working/TN.pkl (deflated 12%)
#   adding: kaggle/working/TP.pkl (deflated 13%)
#   adding: kaggle/working/y_pred.pkl (deflated 7%)
#   adding: kaggle/working/y_pred_argmax.pkl (deflated 89%)
#   adding: kaggle/working/FP.pkl (deflated 13%)
#   adding: kaggle/working/f2_score.pkl (deflated 11%)
#   adding: kaggle/working/y_true_argmax.pkl (deflated 87%)
#   adding: kaggle/working/precision.pkl (deflated 11%)
#   adding: kaggle/working/checkpoint_lstm/ (stored 0%)
#   adding: kaggle/working/checkpoint_lstm/.index (deflated 62%)
#   adding: kaggle/working/checkpoint_lstm/checkpoint (deflated 34%)
#   adding: kaggle/working/checkpoint_lstm/.data-00000-of-00001 (deflated 7%)
